# %% [markdown]
# ### 7.1   Binary tree
#
# A binary tree is a non-linear data structure that represents the hierarchical relationship between ancestors and descendants, embodying the divide-and-conquer logic of "splitting into two".
#
# In a binary tree, except for leaf nodes, all other nodes contain child nodes and non-empty subtrees.

# %% [markdown]
# Figure 7-1   Parent Node, child Node, subtree
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 7.1.3   Common types of binary trees
#
# perfect binary tree, all levels of nodes are fully filled.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# complete binary tree has only the bottom level nodes not fully filled, and the bottom level nodes are filled as far left as possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  full binary tree has all nodes except leaf nodes having two children.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# balanced binary tree, the absolute difference in height between the left and right subtrees of any node does not exceed 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7.2   Binary tree traversal
